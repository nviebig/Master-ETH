# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
I_a = 1.0  # Average intensity
I_b = 1  # Modulation amplitude
delta = 1  # Phase offset

# Create a grid of (x, y) points
x = np.linspace(-10, 10, 500)
y = np.linspace(-10, 10, 500)
X, Y = np.meshgrid(x, y)

# Define the phase function (here we use a simple radial pattern for demonstration)
phi = np.sqrt(X**2 + Y**2)

# Calculate the intensity distribution
I = I_a + I_b * np.cos(phi + delta)

# Plot the intensity distribution
plt.figure(figsize=(8, 6))
plt.pcolormesh(X, Y, I, shading='auto', cmap='viridis')
plt.colorbar(label='Intensity')
plt.title('Interference Pattern Intensity Distribution')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import scipy
import diffractio
print(scipy.__version__)
print(diffractio.__version__)
# Out:
# 1.5.4
# 0.2.4

# %%
from diffractio import degrees, mm, plt, sp, um, np
from diffractio.scalar_masks_X import Scalar_mask_X
from diffractio.scalar_masks_XZ import Scalar_mask_XZ
from diffractio.scalar_sources_X import Scalar_source_X

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from diffractio import Grating, Wavefront, plot_field
#       3 # Constants
#       4 wavelength = 632e-9  # Wavelength in meters (632 nm)
#
# ImportError: cannot import name 'Grating' from 'diffractio' (/Users/niklasviebig/Desktop/Ausbilding/ETH/Master/Semester Project Gratting Nuller /.venv/lib/python3.8/site-packages/diffractio/__init__.py)
